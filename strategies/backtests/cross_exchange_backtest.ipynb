# %% [markdown]
# # Cross-exchange arb backtest
#
# Historical replay of `CrossExchangeStrategy` against BigQuery-archived ticks.
#
# **Status:** stub. Phase 2 work — paper trading is the validation gate today (see project README).
#
# ## Inputs
#
# - `arb_market_data.ticks` (90-day partition window), spot instruments only
# - L2 order book snapshots if available (for slippage validation)
#
# ## Outputs to verify against paper trading
#
# - Gross spread distribution per (venue_pair, asset)
# - Persistence — how long a spread stays > 8 bps after detection
# - Realized fill ratio: how often we actually capture the modeled net edge

# %%
# Reuse the canonical net-edge + slippage math.
import sys
sys.path.insert(0, '../..')
from shared.utils.fee_calculator import calculate_net_edge, taker_fee_bps  # noqa: E402
from shared.utils.slippage_model import estimate_size_tier_bps           # noqa: E402

# %%
# TODO: replay ticks from BigQuery, run CrossExchangeStrategy, compute PnL
# against actual book depth at fill time.
